# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../reports/test_predictions.csv")

# %%
df.head()

# %%
mask_transaction = df['FLAG_TRANSACTION'] == 1

# df[mask_transaction][['POINTS_PURCHASED', 'points_purchased']]
print(df[mask_transaction][['FLAG_TRANSACTION', 'convert_proba']].mean())
print(df[~mask_transaction][['FLAG_TRANSACTION', 'convert_proba']].mean())

# df[mask_transaction].count() # 137
# print(len(df))

# %%
# np.log(df['points_purchased'])
